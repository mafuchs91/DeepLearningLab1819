# %%
import numpy as np
import _pickle as cPickle
import os
import gzip

# %% [markdown]
# # First exercise: Classifying MNIST with MLPs
# In this exercise you will implement a Neural Network (or MLP) and classify the MNIST digits with it.
# MNIST is a "well hung" dataset that has been used a lot over the years to benchmark different classification algorithms.
# To learn more about it have a look here: http://yann.lecun.com/exdb/mnist/ .

# %% [markdown]
# # Data Loading
# We first define a function for downloading and loading MNIST.
# **WARNING**: Executing it will obviously use up some space on your machine ;).

# %%
def mnist(datasets_dir='./data'):
    if not os.path.exists(datasets_dir):
        os.mkdir(datasets_dir)
    data_file = os.path.join(datasets_dir, 'mnist.pkl.gz')
    if not os.path.exists(data_file):
        print('... downloading MNIST from the web')
        try:
            import urllib
            urllib.urlretrieve('http://google.com')
        except AttributeError:
            import urllib.request as urllib
        url = 'http://www.iro.umontreal.ca/~lisa/deep/data/mnist/mnist.pkl.gz'
        urllib.urlretrieve(url, data_file)

    print('... loading data')
    # Load the dataset
    f = gzip.open(data_file, 'rb')
    try:
        train_set, valid_set, test_set = cPickle.load(f, encoding="latin1")
    except TypeError:
        train_set, valid_set, test_set = cPickle.load(f)
    f.close()

    test_x, test_y = test_set
    test_x = test_x.astype('float32')
    test_x = test_x.astype('float32').reshape(test_x.shape[0], 1, 28, 28)
    test_y = test_y.astype('int32')
    valid_x, valid_y = valid_set
    valid_x = valid_x.astype('float32')
    valid_x = valid_x.astype('float32').reshape(valid_x.shape[0], 1, 28, 28)
    valid_y = valid_y.astype('int32')
    train_x, train_y = train_set
    train_x = train_x.astype('float32').reshape(train_x.shape[0], 1, 28, 28)
    train_y = train_y.astype('int32')
    rval = [(train_x, train_y), (valid_x, valid_y), (test_x, test_y)]
    print('... done loading data')
    return rval

# %% [markdown]
# # Neural Network Layers
# We now define "bare bone" neural network layers.
# The parts marked with **TODO** are where you should finish the implementation!
# Conceptually we will implement the layers as follows:
#
# Each layer has a constructor that takes an input layer plus some additional arguments such as layer size and the activation function name. The layer then uses the provided input layer to compute the layer dimensions, weight shapes, etc. and setup all auxilliary variables.
#
# Each layer then has to provide three functions (as defined in the Layer class below): *output_shape()*, *fprop()* and *brop()*. The output_shape function is used to figure out the shape for the next layer and the *fprop()/bprop()* functions are used to compute forward and backward passes through the network.

# %%
# start by defining simple helpers
def sigmoid(x):
    return 1.0/(1.0+np.exp(-x))

def sigmoid_d(x):
    # TODO ################
    # TODO: implement this!
    # TODO ################
    x = sigmoid(x)*(1-sigmoid(x))
    return x

def tanh(x):
    return np.tanh(x)

def tanh_d(x):
    # TODO ################
    # TODO: implement this!
    # TODO ################
    x = 1-tanh(x)**2
    return x

def relu(x):
    return np.maximum(0.0, x)

def relu_d(x):
    # TODO ################
    # TODO: implement this!
    # TODO ################
    x = np.heaviside(x,0)
    return x

def softmax(x, axis=1):
    # to make the softmax a "safe" operation we will 
    # first subtract the maximum along the specified axis
    # so that np.exp(x) does not blow up!
    # Note that this does not change the output.
    x_max = np.max(x, axis=axis, keepdims=True)
    x_safe = x - x_max
    e_x = np.exp(x_safe)
    return e_x / np.sum(e_x, axis=axis, keepdims=True)

def one_hot(labels):
    """this creates a one hot encoding from a flat vector:
    i.e. given y = [0,2,1]
     it creates y_one_hot = [[1,0,0], [0,0,1], [0,1,0]]
    """
    classes = np.unique(labels)
    n_classes = classes.size
    one_hot_labels = np.zeros(labels.shape + (n_classes,))
    for c in classes:
        one_hot_labels[labels == c, c] = 1
    return one_hot_labels

def unhot(one_hot_labels):
    """ Invert a one hot encoding, creating a flat vector """
    return np.argmax(one_hot_labels, axis=-1)

# then define an activation function class
class Activation(object):
    
    def __init__(self, tname):
        if tname == 'sigmoid':
            self.act = sigmoid
            self.act_d = sigmoid_d
        elif tname == 'tanh':
            self.act = tanh
            self.act_d = tanh_d
        elif tname == 'relu':
            self.act = relu
            self.act_d = relu_d
        else:
            raise ValueError('Invalid activation function.')
            
    def fprop(self, input):
        # we need to remember the last input
        # so that we can calculate the derivative with respect
        # to it later on
        self.last_input = input
        self.last_output = self.act(input)
        return self.act(input)
    
    def bprop(self, output_grad):
        return output_grad * self.act_d(self.last_input)

# define a base class for layers
class Layer(object):
    
    def fprop(self, input):
        """ Calculate layer output for given input 
            (forward propagation). 
        """
        raise NotImplementedError('This is an interface class, please use a derived instance')

    def bprop(self, output_grad):
        """ Calculate input gradient and gradient 
            with respect to weights and bias (backpropagation). 
        """
        raise NotImplementedError('This is an interface class, please use a derived instance')

    def output_size(self):
        """ Calculate size of this layer's output.
        input_shape[0] is the number of samples in the input.
        input_shape[1:] is the shape of the feature.
        """
        raise NotImplementedError('This is an interface class, please use a derived instance')

# define a base class for loss outputs
# an output layer can then simply be derived
# from both Layer and Loss 
class Loss(object):

    def loss(self, output, output_net):
        """ Calculate mean loss given real output and network output. """
        raise NotImplementedError('This is an interface class, please use a derived instance')

    def input_grad(self, output, output_net):
        """ Calculate input gradient real output and network output. """
        raise NotImplementedError('This is an interface class, please use a derived instance')

# define a base class for parameterized things        
class Parameterized(object):
    
    def params(self):
        """ Return parameters (by reference) """
        raise NotImplementedError('This is an interface class, please use a derived instance')
    
    def grad_params(self):
        """ Return accumulated gradient with respect to params. """
        raise NotImplementedError('This is an interface class, please use a derived instance')

# define a container for providing input to the network
class InputLayer(Layer):
    
    def __init__(self, input_shape):
        if not isinstance(input_shape, tuple):
            raise ValueError("InputLayer requires input_shape as a tuple")
        self.input_shape = input_shape

    def output_size(self):
        return self.input_shape
    
    def fprop(self, input):
        self.input = input
        return input
    
    def bprop(self, output_grad):
        return output_grad
        
class FullyConnectedLayer(Layer, Parameterized):
    """ A standard fully connected hidden layer, as discussed in the lecture.
    """
    
    def __init__(self, input_layer, num_units, 
                 init_stddev, activation_fun=Activation('relu')):
        self.num_units = num_units
        self.activation_fun = activation_fun
        self.input_layer = input_layer
        # the input shape will be of size (batch_size, num_units_prev) 
        # where num_units_prev is the number of units in the input 
        # (previous) layer
        self.input_shape = input_layer.output_size()
        # TODO ################################
        # TODO: implement weight initialization
        # TODO ################################
        # this is the weight matrix it should have shape: (num_units_prev, num_units)
        self.W = init_stddev*np.random.randn(self.input_shape[1], self.num_units)  #FIXME
        # and this is the bias vector of shape: (num_units)
        self.b = np.zeros((1,self.num_units))  #FIXME
        # create dummy variables for parameter gradients
        # no need to change these here!
        self.dW = None
        self.db = None
    
    def output_size(self):
        return (self.input_shape[0], self.num_units)
    
    def fprop(self, input):
        # TODO ################################################
        # TODO: implement forward propagation
        # NOTE: you should also handle the case were 
        #       activation_fun is None (meaning no activation)
        #       then this is simply a linear layer
        # TODO ###############################################
        # you again want to cache the last_input for the bprop
        # implementation below!
        # x oder z!!!
        self.last_input = input
        
        a = np.dot(input, self.W) + self.b
        if self.activation_fun is None:
            return a
        else:
            return self.activation_fun.fprop(a)
        # NOTE: Use numpy dot product
        # h = t(a), a = W * x + b 
            
        #FIXME
        #raise NotImplementedError("You should implement this!")
        #return np.zeros(self.output_size)
    
        # the output gradient wrt the activation                  
    def bprop(self, output_grad):
        """ Calculate input gradient (backpropagation). """
        # TODO ################################
        # TODO: implement backward propagation
        # TODO ###############################
        
        # HINT: you may have to divide dW and db by n
        #       to make gradient checking work 
        #       OR you divide the gradient in the output layer by n
        n = output_grad.shape[0]
        # accumulate gradient wrt. the parameters first
        # we will need to store these to later update
        # the network after a few forward backward passes
        # NOTE: you should also handle the case were 
        #       activation_fun is None (meaning no activation)
        # the gradient wrt. W should be stored as self.dW
        # the gradient wrt. b should be stored as self.db
        # raise NotImplementedError("you should implement this")
        # NOTE: self.dW is also a numpy dot product   
        if self.activation_fun is not None:
            delta = self.activation_fun.bprop(output_grad)
        else:
            delta = output_grad
        self.dW = np.dot(self.last_input.T, delta)  #FIXME
        self.db = delta.sum(axis = 0, keepdims=True) #FIXME
        # the gradient wrt. the input should be calculated here
        grad_input = np.dot(delta, self.W.T)
        return grad_input
        
    def params(self):
        return self.W, self.b

    def grad_params(self):
        return self.dW, self.db

# finally we specify the interface for output layers 
# which are layers that also have a loss function
# we will implement two output layers:
#  a Linear, and Softmax (Logistic Regression) layer
# The difference between output layers and and normal 
# layers is that they will be called to compute the gradient
# of the loss through input_grad(). bprop will never 
# be called on them!
class LinearOutput(Layer, Loss):
    """ A simple linear output layer that  
        uses a squared loss (e.g. should be used for regression)
    """
    def __init__(self, input_layer):
        self.input_size = input_layer.output_size()
        
    def output_size(self):
        return (1,)
        
    def fprop(self, input):
        return input

    def bprop(self, output_grad):
        raise NotImplementedError(
            'LinearOutput should only be used as the last layer of a Network'
            + ' bprop() should thus never be called on it!'
        )
    
    def input_grad(self, Y, Y_pred):
        # TODO ####################################
        # TODO: implement gradient of squared loss
        # TODO ####################################
        return (1/len(Y))*(Y_pred-Y) #FIXME FIXED

    def loss(self, Y, Y_pred):
        loss = 0.5 * np.square(Y_pred - Y)
        return np.mean(np.sum(loss, axis=1))

class SoftmaxOutput(Layer, Loss):
    """ A softmax output layer that calculates 
        the negative log likelihood as loss
        and should be used for classification.
    """
    
    def __init__(self, input_layer):
        self.input_size = input_layer.output_size()
        
    def output_size(self):
        return (1,)
    
    def fprop(self, input):
        return softmax(input)
    
    def bprop(self, output_grad):
        raise NotImplementedError(
            'SoftmaxOutput should only be used as the last layer of a Network'
            + ' bprop() should thus never be called on it!'
        )
    
    def input_grad(self, Y, Y_pred):
        # TODO #######################################################
        # TODO: implement gradient of the negative log likelihood loss
        # TODO #######################################################
        # HINT: since this would involve taking the log 
        #       of the softmax (which is np.exp(x)/np.sum(x, axis=1))
        #       this gradient computation can be simplified a lot,
        #       you may find a connection to the LinearOutput layer!
        # return np.zeros_like(Y_pred)
        return (-Y+Y_pred)/len(Y)
                          
    def loss(self, Y, Y_pred):
        # Assume one-hot encoding of Y
        out = Y_pred
        # to make the loss numerically stable 
        # you should add an epsilon in the log ;)
        eps = 1e-10
        # TODO ####################################
        # calculate negative log likelihood
        # TODO ####################################
        # loss = np.zeros_like(out) #FIXME
        loss = -np.log(eps+out)*Y                   
        return np.mean(np.sum(loss, axis=1))

# %% [markdown]
# # Neural Network class
# With all layers in place (and properly implemented by you) we can finally define a neural network.
# For our purposes a neural network is simply a collection of layers which we will cycle through and on which we will call fprop and bprop to compute partial derivatives with respect to the input and the parameters.
#
# Pay special attention to the *check_gradients()* function in which you should implement automatic differentiation. This function will become your best friend when checking the correctness of your implementation.

# %%
a = np.ndarray([0,2])
print(a)
b = np.array([[2,3]])
for i in range(3):
    a = np.concatenate((a,b))
a
# Out:
# []
# array([[2., 3.],
#        [2., 3.],
#        [2., 3.]])

# %%
class NeuralNetwork:
    """ Our Neural Network container class.
    """
    def __init__(self, layers):
        self.layers = layers
        self.plot_data = np.ndarray([0,3])
        
    def _loss(self, X, Y):
        Y_pred = self.predict(X)
        return self.layers[-1].loss(Y, Y_pred)

    def predict(self, X):
        """ Calculate an output Y for the given input X. """
        # TODO ##########################################
        # TODO: implement forward pass through all layers
        # TODO ##########################################
        # iterate through all layers passing last output to next input
        for layer in self.layers:
            X = layer.fprop(X)
        Y_pred = X

        return Y_pred
    
    def backpropagate(self, Y, Y_pred, upto=0):
        """ Backpropagation of partial derivatives through 
            the complete network up to layer 'upto'
        """
        # Takes last element from list layers and calculates gradient 
        next_grad = self.layers[-1].input_grad(Y, Y_pred)
        # TODO ##########################################
        # TODO: implement backward pass through all layers
        # TODO ##########################################
        for x in range(2,len(self.layers)-upto +1):
            next_grad = self.layers[-x].bprop(next_grad)
        return next_grad
    
    def classification_error(self, X, Y):
        """ Calculate error on the given data 
            assuming they are classes that should be predicted. 
        """
        Y_pred = unhot(self.predict(X))
        error = Y_pred != Y
        return np.mean(error)
    
    def sgd_epoch(self, X, Y, learning_rate, batch_size):
        n_samples = X.shape[0]
        n_batches = n_samples // batch_size
        for b in range(n_batches):
            # TODO #####################################
            # Implement stochastic gradient descent here
            # TODO #####################################
            # start by extracting a batch from X and Y
            # (you can assume the inputs are already shuffled)
            X_batch = np.array_split(X, n_batches)[b]
            Y_batch = np.array_split(Y, n_batches)[b]
            # TODO: then forward and backward propagation + updates
            # HINT: layer.params() returns parameters *by reference*
            #       so you can easily update in-place
            Y_batch_pred = self.predict(X_batch)
            self.backpropagate(Y_batch,Y_batch_pred)
            for layer in self.layers:
                if isinstance(layer, FullyConnectedLayer):
                    layer.W = layer.params()[0] - learning_rate * layer.grad_params()[0]
                    layer.d = layer.params()[1] - learning_rate * layer.grad_params()[1]
                    
    
    def gd_epoch(self, X, Y, learning_rate):
        # TODO ##################################################
        # Implement batch gradient descent here
        # A few hints:
        #   There are two strategies you can follow:
        #   Either shove the whole dataset throught the network
        #   at once (which can be problematic for large datasets)
        #   or run through it batch wise as in the sgd approach
        #   and accumulate the gradients for all parameters as
        #   you go through the data. Either way you should then
        #   do one gradient step after you went through the
        #   complete dataset!
        # TODO ##################################################
        Y_pred = self.predict(X)
        self.backpropagate(Y,Y_pred)
        for layer in self.layers:
            if isinstance(layer, FullyConnectedLayer):
                layer.W = layer.params()[0] - learning_rate * layer.grad_params()[0]
                layer.d = layer.params()[1] - learning_rate * layer.grad_params()[1]
    
    def train(self, X, Y, X_valid, Y_valid, learning_rate=0.1, max_epochs=100, batch_size=64,
              descent_type="sgd", y_one_hot=True):

        """ Train network on the given data. """
        n_samples = X.shape[0]
        n_batches = n_samples // batch_size
        if y_one_hot:
            Y_train = one_hot(Y)
            Y_valid_encoded = one_hot(Y_valid)
        else:
            Y_train = Y
            Y_valid_encoded = Y_valid 
        print("... starting training")
        for e in range(max_epochs+1):
            if descent_type == "sgd":
                self.sgd_epoch(X, Y_train, learning_rate, batch_size)
            elif descent_type == "gd":
                self.gd_epoch(X, Y_train, learning_rate)
            else:
                raise NotImplementedError("Unknown gradient descent type {}".format(descent_type))

            # Output error on the training data
            train_loss = self._loss(X, Y_train)
            train_error = self.classification_error(X, Y)
            print('epoch {:.4f}, loss {:.4f}, train error {:.4f}'.format(e, train_loss, train_error))
            # TODO ##################################################
            # compute error on validation data:
            # simply make the function take validation data as input
            # and then compute errors here and print them
            # TODO ##################################################
            validation_error = self.classification_error(X_valid, Y_valid)
            validation_loss = self._loss(X_valid, Y_valid_encoded)
            print('validation loss {:.4f}'.format(validation_loss))
            print('validation error {:.4f}'.format(validation_error))
            #store value touples for plot
            self.plot_data = np.concatenate((self.plot_data,np.array([[train_loss, validation_loss,e]])))
            
    def check_gradients(self, X, Y):
        """ Helper function to test the parameter gradients for
        correctness. """
        for l, layer in enumerate(self.layers):
            # only use Fully connected layers(input layers are not parameterized)
            if isinstance(layer, Parameterized):
                print('checking gradient for layer {}'.format(l))
                for p, param in enumerate(layer.params()):
                    # we iterate through all parameters
                    param_shape = param.shape
                    # define functions for conveniently swapping
                    # out parameters of this specific layer and 
                    # computing loss and gradient with these 
                    # changed parametrs
                    def output_given_params(param_new):
                        """ A function that will compute the output 
                            of the network given a set of parameters
                        """
                        # copy provided parameters
                        param[:] = np.reshape(param_new, param_shape)
                        # return computed loss
                        return self._loss(X, Y)

                    def grad_given_params(param_new):
                        """A function that will compute the gradient 
                           of the network given a set of parameters
                        """
                        # copy provided parameters
                        param[:] = np.reshape(param_new, param_shape)
                        # Forward propagation through the net
                        Y_pred = self.predict(X)
                        # Backpropagation of partial derivatives
                        self.backpropagate(Y, Y_pred, upto=l)
                        # to match bias b, array b needs to be changed from (1,k)
                        # to (n,k) with same identical row vector
                        return np.ravel(self.layers[l].grad_params()[p])

                    # let the initial parameters be the ones that
                    # are currently placed in the network and flatten them
                    # to a vector for convenient comparisons, printing etc.
                    param_init = np.ravel(np.copy(param))
                    
                    # To debug you network's gradients use scipys
                    # gradient checking!

                    epsilon = 1e-5
                    import scipy.optimize
                    err = scipy.optimize.check_grad(output_given_params, 
                          grad_given_params, param_init) 
                    print('diff scipy {:.2e}'.format(err))
                    assert(err < epsilon)
                    
                    # reset the parameters to their initial values
                    param[:] = np.reshape(param_init, param_shape)

# %% [markdown]
# # Gradient Checking
# After implementing everything it is always a good idea to setup some layers and perform gradient
# checking on random data. **Note** that this is only an example! It is not a useful network architecture ;). We also expect you to play around with this to test all your implemented components.

# %%
input_shape = (5, 10)
n_labels = 20
layers = [InputLayer(input_shape)]

layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=15,
                init_stddev=0.1,
                activation_fun=Activation('sigmoid')
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=6,
                init_stddev=0.1,
                activation_fun=Activation('tanh')
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=n_labels,
                init_stddev=0.1,
                activation_fun=Activation('relu')
))
layers.append(SoftmaxOutput(layers[-1]))
nn = NeuralNetwork(layers)

# %%
# create random data
X = np.random.normal(size=input_shape)
# and random labels
Y = np.zeros((input_shape[0], n_labels))
for i in range(Y.shape[0]):
    idx = np.random.randint(n_labels)
    Y[i, idx] = 1

# %%
nn.check_gradients(X, Y)
# Out:
# checking gradient for layer 1
# diff scipy 3.28e-07
# diff scipy 9.13e-08
# checking gradient for layer 2
# diff scipy 2.41e-07
# diff scipy 8.65e-08
# checking gradient for layer 3
# diff scipy 2.08e-07
# diff scipy 8.24e-08

# %% [markdown]
# # Training on MNIST
# Finally we can let our network run on the MNIST dataset!

# %% [markdown]
# First load the data and reshape it.

# %%
# load
Dtrain, Dval, Dtest = mnist()
X_train, y_train = Dtrain
X_valid, y_valid = Dval
X_test, y_test = Dtest
# Out:
# ... loading data
# ... done loading data

# %% [markdown]
# *Dtrain* contains 50k images which are of size 28 x 28 pixels. Hence:

# %%
print("X_train shape: {}".format(np.shape(X_train)))
print("y_train shape: {}".format(np.shape(y_train)))
# Out:
# X_train shape: (50000, 1, 28, 28)
# y_train shape: (50000,)
# y_train shape: (10000, 1, 28, 28)

# %% [markdown]
# y_train will automatically be converted in the *train()* function to one_hot encoding.
#
#
# But we need to reshape X_train, as our Network expects flat vectors of size 28*28 as input!

# %%
X_train = X_train.reshape(X_train.shape[0], -1)
print("Reshaped X_train size: {}".format(X_train.shape))
X_valid = X_valid.reshape((X_valid.shape[0], -1))
print("Reshaped X_valid size: {}".format(X_valid.shape))
X_test = X_test.reshape((X_test.shape[0], -1))
print("Reshaped X_test size: {}".format(X_test.shape))
# Out:
# Reshaped X_train size: (50000, 784)
# Reshaped X_valid size: (10000, 784)
# Reshaped X_test size: (10000, 784)

# %% [markdown]
# Ah, much better ;-)!
#
# Now we can finally really start training a Network!
#
#
# I pre-defined a small Network for you below. Again This is not really a good default and will not produce state of the art results. Please play around with this a bit. See how different activation functions and training procedures (gd / sgd) affect the result.

# %%
import time

# Setup a small MLP / Neural Network
# we can set the first shape to None here to indicate that
# we will input a variable number inputs to the network
input_shape = (None, 28*28)
layers = [InputLayer(input_shape)]
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=400,
                init_stddev=0.01,
                activation_fun=Activation('relu')
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=10,
                init_stddev=0.01,
                # last layer has no nonlinearity 
                # (softmax will be applied in the output layer)
                activation_fun=None 
))
layers.append(SoftmaxOutput(layers[-1]))

nn = NeuralNetwork(layers)
# Train neural network
t0 = time.time()
nn.train(X_train, y_train, X_valid, y_valid, learning_rate=0.2, 
         max_epochs=20, batch_size=50, y_one_hot=True, descent_type="sgd")
t1 = time.time()
print('Duration: {:.1f}s'.format(t1-t0))
# Out:
# ... starting training
# -------------------------------------------
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-97-6585a3a7b73c> in <module>
#      26 t0 = time.time()
#      27 nn.train(X_train, y_train, X_valid, y_valid, learning_rate=0.2,
# ---> 28          max_epochs=20, batch_size=50, y_one_hot=True, descent_type="sgd")
#      29 t1 = time.time()
#      30 print('Duration: {:.1f}s'.format(t1-t0))
#
# <ipython-input-96-ad7e8eba957e> in train(self, X, Y, X_valid, Y_valid, learning_rate, max_epochs, batch_size, descent_type, y_one_hot)
#     101         for e in range(max_epochs+1):
#     102             if descent_type == "sgd":
# --> 103                 self.sgd_epoch(X, Y_train, learning_rate, batch_size)
#     104             elif descent_type == "gd":
#     105                 self.gd_epoch(X, Y_train, learning_rate)
#
# <ipython-input-96-ad7e8eba957e> in sgd_epoch(self, X, Y, learning_rate, batch_size)
#      59             #       so you can easily update in-place
#      60             Y_batch_pred = self.predict(X_batch)
# ---> 61             self.backpropagate(Y_batch,Y_batch_pred)
#      62             for layer in self.layers:
#      63                 if isinstance(layer, FullyConnectedLayer):
#
# <ipython-input-96-ad7e8eba957e> in backpropagate(self, Y, Y_pred, upto)
#      33         # TODO ##########################################
#      34         for x in range(2,len(self.layers)-upto +1):
# ---> 35             next_grad = self.layers[-x].bprop(next_grad)
#      36         return next_grad
#      37
#
# <ipython-input-4-b91b0a8eaf0c> in bprop(self, output_grad)
#     226         self.db = delta.sum(axis = 0, keepdims=True) #FIXME
#     227         # the gradient wrt. the input should be calculated here
# --> 228         grad_input = np.dot(delta, self.W.T)
#     229         return grad_input
#     230
#
# KeyboardInterrupt:

# %% [markdown]
# # Figure out a reasonable Network that achieves good performance
# As the last part of this task, setup a network that works well and gets reasonable accuracy, say ~ 1-3 percent error on the **validation set**.
# Train this network on the complete data and compute the **test error**.
#
# Visualize the validation loss and training loss for each iteration in a plot, e.g. using matplotlib

# %%
We need to concatenate training and valiation set

# %%
X_complete = np.concatenate((X_train, X_valid), axis=0)
print("X_complete shape:",X_complete.shape)
y_complete = np.concatenate((y_train, y_valid), axis=0)
print("y_complete shape:",y_complete.shape)
# Out:
# X_complete shape: (60000, 784)
# y_complete shape: (60000,)

# %%
import time

# Setup a small MLP / Neural Network
# we can set the first shape to None here to indicate that
# we will input a variable number inputs to the network
input_shape = (None, 28*28)
layers = [InputLayer(input_shape)]
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=400,
                init_stddev=0.01,
                activation_fun=Activation('relu')
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=10,
                init_stddev=0.01,
                # last layer has no nonlinearity 
                # (softmax will be applied in the output layer)
                activation_fun=None 
))
layers.append(SoftmaxOutput(layers[-1]))

nn = NeuralNetwork(layers)
# Train neural network
t0 = time.time()
nn.train(X_complete, y_complete, X_test, y_test, learning_rate=0.5, 
         max_epochs=350, batch_size=50, y_one_hot=True, descent_type="gd")
t1 = time.time()
print('Duration: {:.1f}s'.format(t1-t0))
# Out:
# ... starting training
# epoch 0.0000, loss 2.2820, train error 0.5269
# validation loss 2.2813
# validation error 0.5155
# epoch 1.0000, loss 2.2624, train error 0.4323
# validation loss 2.2613
# validation error 0.4186
# epoch 2.0000, loss 2.2371, train error 0.3955
# validation loss 2.2355
# validation error 0.3808
# epoch 3.0000, loss 2.2030, train error 0.3775
# validation loss 2.2007
# validation error 0.3632
# epoch 4.0000, loss 2.1566, train error 0.3649
# validation loss 2.1533
# validation error 0.3563
# epoch 5.0000, loss 2.0945, train error 0.3502
# validation loss 2.0901
# validation error 0.3419
# epoch 6.0000, loss 2.0138, train error 0.3300
# validation loss 2.0078
# validation error 0.3215
# epoch 7.0000, loss 1.9128, train error 0.3077
# validation loss 1.9049
# validation error 0.2976
# epoch 8.0000, loss 1.7926, train error 0.2905
# validation loss 1.7824
# validation error 0.2823
# epoch 9.0000, loss 1.6584, train error 0.2819
# validation loss 1.6457
# validation error 0.2739
# epoch 10.0000, loss 1.5189, train error 0.2754
# validation loss 1.5039
# validation error 0.2699
# epoch 11.0000, loss 1.3838, train error 0.2654
# validation loss 1.3670
# validation error 0.2592
# epoch 12.0000, loss 1.2607, train error 0.2492
# validation loss 1.2425
# validation error 0.2427
# epoch 13.0000, loss 1.1531, train error 0.2322
# validation loss 1.1341
# validation error 0.2270
# epoch 14.0000, loss 1.0614, train error 0.2182
# validation loss 1.0418
# validation error 0.2149
# epoch 15.0000, loss 0.9838, train error 0.2073
# validation loss 0.9639
# validation error 0.2029
# epoch 16.0000, loss 0.9182, train error 0.1984
# validation loss 0.8981
# validation error 0.1941
# epoch 17.0000, loss 0.8626, train error 0.1903
# validation loss 0.8423
# validation error 0.1859
# epoch 18.0000, loss 0.8150, train error 0.1825
# validation loss 0.7948
# validation error 0.1783
# epoch 19.0000, loss 0.7741, train error 0.1765
# validation loss 0.7538
# validation error 0.1715
# epoch 20.0000, loss 0.7385, train error 0.1711
# validation loss 0.7183
# validation error 0.1658
# epoch 21.0000, loss 0.7075, train error 0.1666
# validation loss 0.6873
# validation error 0.1607
# epoch 22.0000, loss 0.6802, train error 0.1618
# validation loss 0.6601
# validation error 0.1563
# epoch 23.0000, loss 0.6559, train error 0.1580
# validation loss 0.6357
# validation error 0.1529
# epoch 24.0000, loss 0.6344, train error 0.1546
# validation loss 0.6145
# validation error 0.1488
# epoch 25.0000, loss 0.6155, train error 0.1515
# validation loss 0.5950
# validation error 0.1476
# epoch 26.0000, loss 0.6011, train error 0.1513
# validation loss 0.5823
# validation error 0.1472
# epoch 27.0000, loss 0.6030, train error 0.1597
# validation loss 0.5811
# validation error 0.1518
# epoch 28.0000, loss 0.6925, train error 0.2102
# validation loss 0.6812
# validation error 0.2059
# epoch 29.0000, loss 0.9048, train error 0.3219
# validation loss 0.8847
# validation error 0.3222
# epoch 30.0000, loss 1.3573, train error 0.3069
# validation loss 1.3663
# validation error 0.3091
# epoch 31.0000, loss 1.1717, train error 0.3976
# validation loss 1.1721
# validation error 0.3948
# epoch 32.0000, loss 0.8969, train error 0.3291
# validation loss 0.8773
# validation error 0.3164
# epoch 33.0000, loss 0.6597, train error 0.1850
# validation loss 0.6412
# validation error 0.1797
# epoch 34.0000, loss 0.5962, train error 0.1745
# validation loss 0.5762
# validation error 0.1653
# epoch 35.0000, loss 0.5524, train error 0.1437
# validation loss 0.5336
# validation error 0.1345
# epoch 36.0000, loss 0.5310, train error 0.1453
# validation loss 0.5114
# validation error 0.1406
# epoch 37.0000, loss 0.5147, train error 0.1364
# validation loss 0.4954
# validation error 0.1280
# epoch 38.0000, loss 0.5043, train error 0.1384
# validation loss 0.4852
# validation error 0.1337
# epoch 39.0000, loss 0.4946, train error 0.1344
# validation loss 0.4755
# validation error 0.1260
# epoch 40.0000, loss 0.4897, train error 0.1383
# validation loss 0.4712
# validation error 0.1321
# epoch 41.0000, loss 0.4843, train error 0.1367
# validation loss 0.4654
# validation error 0.1287
# epoch 42.0000, loss 0.4853, train error 0.1426
# validation loss 0.4676
# validation error 0.1378
# epoch 43.0000, loss 0.4832, train error 0.1421
# validation loss 0.4647
# validation error 0.1360
# epoch 44.0000, loss 0.4913, train error 0.1550
# validation loss 0.4750
# validation error 0.1491
# epoch 45.0000, loss 0.4881, train error 0.1505
# validation loss 0.4702
# validation error 0.1449
# epoch 46.0000, loss 0.4996, train error 0.1652
# validation loss 0.4848
# validation error 0.1585
# epoch 47.0000, loss 0.4853, train error 0.1521
# validation loss 0.4677
# validation error 0.1464
# epoch 48.0000, loss 0.4897, train error 0.1601
# validation loss 0.4754
# validation error 0.1532
# epoch 49.0000, loss 0.4674, train error 0.1442
# validation loss 0.4495
# validation error 0.1371
# epoch 50.0000, loss 0.4642, train error 0.1435
# validation loss 0.4497
# validation error 0.1388
# epoch 51.0000, loss 0.4457, train error 0.1344
# validation loss 0.4272
# validation error 0.1285
# epoch 52.0000, loss 0.4415, train error 0.1290
# validation loss 0.4268
# validation error 0.1268
# epoch 53.0000, loss 0.4299, train error 0.1276
# validation loss 0.4110
# validation error 0.1197
# epoch 54.0000, loss 0.4273, train error 0.1218
# validation loss 0.4127
# validation error 0.1183
# epoch 55.0000, loss 0.4220, train error 0.1262
# validation loss 0.4029
# validation error 0.1178
# epoch 56.0000, loss 0.4207, train error 0.1198
# validation loss 0.4067
# validation error 0.1166
# epoch 57.0000, loss 0.4217, train error 0.1279
# validation loss 0.4024
# validation error 0.1186
# epoch 58.0000, loss 0.4198, train error 0.1208
# validation loss 0.4066
# validation error 0.1177
# epoch 59.0000, loss 0.4272, train error 0.1320
# validation loss 0.4079
# validation error 0.1241
# epoch 60.0000, loss 0.4213, train error 0.1226
# validation loss 0.4089
# validation error 0.1187
# epoch 61.0000, loss 0.4328, train error 0.1360
# validation loss 0.4134
# validation error 0.1274
# epoch 62.0000, loss 0.4203, train error 0.1231
# validation loss 0.4085
# validation error 0.1204
# epoch 63.0000, loss 0.4304, train error 0.1356
# validation loss 0.4113
# validation error 0.1258
# epoch 64.0000, loss 0.4144, train error 0.1205
# validation loss 0.4025
# validation error 0.1178
# epoch 65.0000, loss 0.4195, train error 0.1313
# validation loss 0.4006
# validation error 0.1221
# epoch 66.0000, loss 0.4050, train error 0.1157
# validation loss 0.3925
# validation error 0.1140
# epoch 67.0000, loss 0.4054, train error 0.1243
# validation loss 0.3870
# validation error 0.1150
# epoch 68.0000, loss 0.3946, train error 0.1118
# validation loss 0.3814
# validation error 0.1086
# epoch 69.0000, loss 0.3923, train error 0.1186
# validation loss 0.3745
# validation error 0.1097
# epoch 70.0000, loss 0.3848, train error 0.1082
# validation loss 0.3710
# validation error 0.1056
# epoch 71.0000, loss 0.3815, train error 0.1136
# validation loss 0.3641
# validation error 0.1055
# epoch 72.0000, loss 0.3761, train error 0.1051
# validation loss 0.3618
# validation error 0.1033
# epoch 73.0000, loss 0.3726, train error 0.1096
# validation loss 0.3557
# validation error 0.1024
# epoch 74.0000, loss 0.3685, train error 0.1030
# validation loss 0.3540
# validation error 0.1007
# epoch 75.0000, loss 0.3653, train error 0.1065
# validation loss 0.3487
# validation error 0.1004
# epoch 76.0000, loss 0.3620, train error 0.1013
# validation loss 0.3473
# validation error 0.0985
# epoch 77.0000, loss 0.3591, train error 0.1041
# validation loss 0.3429
# validation error 0.0989
# epoch 78.0000, loss 0.3564, train error 0.0999
# validation loss 0.3417
# validation error 0.0961
# epoch 79.0000, loss 0.3539, train error 0.1023
# validation loss 0.3380
# validation error 0.0973
# epoch 80.0000, loss 0.3516, train error 0.0983
# validation loss 0.3368
# validation error 0.0944
# epoch 81.0000, loss 0.3494, train error 0.1008
# validation loss 0.3337
# validation error 0.0954
# epoch 82.0000, loss 0.3473, train error 0.0972
# validation loss 0.3326
# validation error 0.0940
# epoch 83.0000, loss 0.3454, train error 0.0994
# validation loss 0.3300
# validation error 0.0940
# epoch 84.0000, loss 0.3435, train error 0.0964
# validation loss 0.3289
# validation error 0.0930
# epoch 85.0000, loss 0.3418, train error 0.0983
# validation loss 0.3266
# validation error 0.0932
# epoch 86.0000, loss 0.3401, train error 0.0956
# validation loss 0.3256
# validation error 0.0921
# epoch 87.0000, loss 0.3385, train error 0.0974
# validation loss 0.3236
# validation error 0.0924
# epoch 88.0000, loss 0.3370, train error 0.0950
# validation loss 0.3226
# validation error 0.0909
# epoch 89.0000, loss 0.3355, train error 0.0963
# validation loss 0.3208
# validation error 0.0924
# epoch 90.0000, loss 0.3340, train error 0.0945
# validation loss 0.3198
# validation error 0.0900
# epoch 91.0000, loss 0.3326, train error 0.0953
# validation loss 0.3181
# validation error 0.0913
# epoch 92.0000, loss 0.3313, train error 0.0936
# validation loss 0.3171
# validation error 0.0893
# epoch 93.0000, loss 0.3299, train error 0.0945
# validation loss 0.3157
# validation error 0.0901
# epoch 94.0000, loss 0.3286, train error 0.0927
# validation loss 0.3147
# validation error 0.0891
# epoch 95.0000, loss 0.3274, train error 0.0937
# validation loss 0.3133
# validation error 0.0894
# epoch 96.0000, loss 0.3261, train error 0.0924
# validation loss 0.3123
# validation error 0.0889
# epoch 97.0000, loss 0.3249, train error 0.0929
# validation loss 0.3111
# validation error 0.0890
# epoch 98.0000, loss 0.3237, train error 0.0917
# validation loss 0.3101
# validation error 0.0883
# epoch 99.0000, loss 0.3226, train error 0.0922
# validation loss 0.3089
# validation error 0.0879
# epoch 100.0000, loss 0.3214, train error 0.0911
# validation loss 0.3079
# validation error 0.0882
# epoch 101.0000, loss 0.3203, train error 0.0916
# validation loss 0.3068
# validation error 0.0879
# epoch 102.0000, loss 0.3192, train error 0.0906
# validation loss 0.3058
# validation error 0.0879
# epoch 103.0000, loss 0.3181, train error 0.0908
# validation loss 0.3048
# validation error 0.0870
# epoch 104.0000, loss 0.3170, train error 0.0902
# validation loss 0.3038
# validation error 0.0877
# epoch 105.0000, loss 0.3160, train error 0.0902
# validation loss 0.3029
# validation error 0.0865
# epoch 106.0000, loss 0.3149, train error 0.0897
# validation loss 0.3019
# validation error 0.0873
# epoch 107.0000, loss 0.3139, train error 0.0896
# validation loss 0.3010
# validation error 0.0859
# epoch 108.0000, loss 0.3129, train error 0.0891
# validation loss 0.3000
# validation error 0.0868
# epoch 109.0000, loss 0.3119, train error 0.0888
# validation loss 0.2991
# validation error 0.0850
# epoch 110.0000, loss 0.3109, train error 0.0886
# validation loss 0.2982
# validation error 0.0863
# epoch 111.0000, loss 0.3099, train error 0.0882
# validation loss 0.2973
# validation error 0.0848
# epoch 112.0000, loss 0.3089, train error 0.0881
# validation loss 0.2964
# validation error 0.0854
# epoch 113.0000, loss 0.3080, train error 0.0878
# validation loss 0.2956
# validation error 0.0847
# epoch 114.0000, loss 0.3070, train error 0.0876
# validation loss 0.2946
# validation error 0.0845
# epoch 115.0000, loss 0.3061, train error 0.0873
# validation loss 0.2939
# validation error 0.0842
# epoch 116.0000, loss 0.3051, train error 0.0870
# validation loss 0.2929
# validation error 0.0841
# epoch 117.0000, loss 0.3042, train error 0.0868
# validation loss 0.2922
# validation error 0.0841
# epoch 118.0000, loss 0.3033, train error 0.0865
# validation loss 0.2912
# validation error 0.0839
# epoch 119.0000, loss 0.3024, train error 0.0863
# validation loss 0.2905
# validation error 0.0839
# epoch 120.0000, loss 0.3015, train error 0.0861
# validation loss 0.2896
# validation error 0.0835
# epoch 121.0000, loss 0.3006, train error 0.0858
# validation loss 0.2889
# validation error 0.0830
# epoch 122.0000, loss 0.2997, train error 0.0854
# validation loss 0.2880
# validation error 0.0830
# epoch 123.0000, loss 0.2989, train error 0.0852
# validation loss 0.2873
# validation error 0.0823
# epoch 124.0000, loss 0.2980, train error 0.0850
# validation loss 0.2864
# validation error 0.0826
# epoch 125.0000, loss 0.2972, train error 0.0848
# validation loss 0.2858
# validation error 0.0819
# epoch 126.0000, loss 0.2963, train error 0.0846
# validation loss 0.2849
# validation error 0.0822
# epoch 127.0000, loss 0.2955, train error 0.0843
# validation loss 0.2842
# validation error 0.0817
# epoch 128.0000, loss 0.2946, train error 0.0841
# validation loss 0.2833
# validation error 0.0816
# epoch 129.0000, loss 0.2938, train error 0.0839
# validation loss 0.2827
# validation error 0.0812
# epoch 130.0000, loss 0.2930, train error 0.0837
# validation loss 0.2818
# validation error 0.0811
# epoch 131.0000, loss 0.2921, train error 0.0834
# validation loss 0.2812
# validation error 0.0803
# epoch 132.0000, loss 0.2913, train error 0.0832
# validation loss 0.2804
# validation error 0.0802
# epoch 133.0000, loss 0.2905, train error 0.0831
# validation loss 0.2798
# validation error 0.0799
# epoch 134.0000, loss 0.2897, train error 0.0827
# validation loss 0.2789
# validation error 0.0796
# epoch 135.0000, loss 0.2889, train error 0.0826
# validation loss 0.2783
# validation error 0.0801
# epoch 136.0000, loss 0.2881, train error 0.0824
# validation loss 0.2775
# validation error 0.0794
# epoch 137.0000, loss 0.2874, train error 0.0819
# validation loss 0.2769
# validation error 0.0795
# epoch 138.0000, loss 0.2866, train error 0.0818
# validation loss 0.2761
# validation error 0.0783
# epoch 139.0000, loss 0.2858, train error 0.0814
# validation loss 0.2755
# validation error 0.0793
# epoch 140.0000, loss 0.2850, train error 0.0812
# validation loss 0.2747
# validation error 0.0781
# epoch 141.0000, loss 0.2843, train error 0.0810
# validation loss 0.2741
# validation error 0.0790
# epoch 142.0000, loss 0.2835, train error 0.0808
# validation loss 0.2733
# validation error 0.0779
# epoch 143.0000, loss 0.2828, train error 0.0806
# validation loss 0.2727
# validation error 0.0787
# epoch 144.0000, loss 0.2820, train error 0.0803
# validation loss 0.2719
# validation error 0.0777
# epoch 145.0000, loss 0.2813, train error 0.0801
# validation loss 0.2714
# validation error 0.0785
# epoch 146.0000, loss 0.2805, train error 0.0798
# validation loss 0.2706
# validation error 0.0775
# epoch 147.0000, loss 0.2798, train error 0.0795
# validation loss 0.2700
# validation error 0.0780
# epoch 148.0000, loss 0.2790, train error 0.0793
# validation loss 0.2693
# validation error 0.0772
# epoch 149.0000, loss 0.2783, train error 0.0790
# validation loss 0.2687
# validation error 0.0777
# epoch 150.0000, loss 0.2776, train error 0.0789
# validation loss 0.2680
# validation error 0.0768
# epoch 151.0000, loss 0.2769, train error 0.0787
# validation loss 0.2674
# validation error 0.0774
# epoch 152.0000, loss 0.2762, train error 0.0782
# validation loss 0.2667
# validation error 0.0764
# epoch 153.0000, loss 0.2754, train error 0.0781
# validation loss 0.2661
# validation error 0.0765
# epoch 154.0000, loss 0.2747, train error 0.0779
# validation loss 0.2654
# validation error 0.0756
# epoch 155.0000, loss 0.2740, train error 0.0777
# validation loss 0.2648
# validation error 0.0758
# epoch 156.0000, loss 0.2733, train error 0.0774
# validation loss 0.2641
# validation error 0.0751
# epoch 157.0000, loss 0.2726, train error 0.0773
# validation loss 0.2635
# validation error 0.0748
# epoch 158.0000, loss 0.2719, train error 0.0771
# validation loss 0.2629
# validation error 0.0745
# epoch 159.0000, loss 0.2713, train error 0.0768
# validation loss 0.2623
# validation error 0.0745
# epoch 160.0000, loss 0.2706, train error 0.0766
# validation loss 0.2617
# validation error 0.0743
# epoch 161.0000, loss 0.2699, train error 0.0764
# validation loss 0.2611
# validation error 0.0742
# epoch 162.0000, loss 0.2692, train error 0.0762
# validation loss 0.2604
# validation error 0.0740
# epoch 163.0000, loss 0.2685, train error 0.0760
# validation loss 0.2598
# validation error 0.0737
# epoch 164.0000, loss 0.2679, train error 0.0760
# validation loss 0.2592
# validation error 0.0734
# epoch 165.0000, loss 0.2672, train error 0.0757
# validation loss 0.2586
# validation error 0.0729
# epoch 166.0000, loss 0.2666, train error 0.0756
# validation loss 0.2580
# validation error 0.0728
# epoch 167.0000, loss 0.2659, train error 0.0754
# validation loss 0.2574
# validation error 0.0724
# epoch 168.0000, loss 0.2652, train error 0.0751
# validation loss 0.2568
# validation error 0.0723
# epoch 169.0000, loss 0.2646, train error 0.0750
# validation loss 0.2562
# validation error 0.0722
# epoch 170.0000, loss 0.2640, train error 0.0749
# validation loss 0.2556
# validation error 0.0718
# epoch 171.0000, loss 0.2633, train error 0.0747
# validation loss 0.2551
# validation error 0.0717
# epoch 172.0000, loss 0.2627, train error 0.0745
# validation loss 0.2545
# validation error 0.0717
# epoch 173.0000, loss 0.2620, train error 0.0743
# validation loss 0.2539
# validation error 0.0717
# epoch 174.0000, loss 0.2614, train error 0.0741
# validation loss 0.2533
# validation error 0.0715
# epoch 175.0000, loss 0.2608, train error 0.0739
# validation loss 0.2528
# validation error 0.0715
# epoch 176.0000, loss 0.2602, train error 0.0738
# validation loss 0.2522
# validation error 0.0713
# epoch 177.0000, loss 0.2595, train error 0.0736
# validation loss 0.2516
# validation error 0.0710
# epoch 178.0000, loss 0.2589, train error 0.0734
# validation loss 0.2511
# validation error 0.0709
# epoch 179.0000, loss 0.2583, train error 0.0732
# validation loss 0.2505
# validation error 0.0707
# epoch 180.0000, loss 0.2577, train error 0.0729
# validation loss 0.2499
# validation error 0.0702
# epoch 181.0000, loss 0.2571, train error 0.0727
# validation loss 0.2494
# validation error 0.0702
# epoch 182.0000, loss 0.2565, train error 0.0726
# validation loss 0.2488
# validation error 0.0701
# epoch 183.0000, loss 0.2558, train error 0.0724
# validation loss 0.2483
# validation error 0.0698
# epoch 184.0000, loss 0.2552, train error 0.0721
# validation loss 0.2477
# validation error 0.0696
# epoch 185.0000, loss 0.2546, train error 0.0719
# validation loss 0.2472
# validation error 0.0691
# epoch 186.0000, loss 0.2540, train error 0.0717
# validation loss 0.2466
# validation error 0.0691
# epoch 187.0000, loss 0.2535, train error 0.0716
# validation loss 0.2461
# validation error 0.0692
# epoch 188.0000, loss 0.2529, train error 0.0714
# validation loss 0.2456
# validation error 0.0687
# epoch 189.0000, loss 0.2523, train error 0.0713
# validation loss 0.2450
# validation error 0.0687
# epoch 190.0000, loss 0.2517, train error 0.0712
# validation loss 0.2445
# validation error 0.0686
# epoch 191.0000, loss 0.2511, train error 0.0710
# validation loss 0.2440
# validation error 0.0684
# epoch 192.0000, loss 0.2505, train error 0.0708
# validation loss 0.2434
# validation error 0.0683
# epoch 193.0000, loss 0.2500, train error 0.0707
# validation loss 0.2429
# validation error 0.0679
# epoch 194.0000, loss 0.2494, train error 0.0706
# validation loss 0.2424
# validation error 0.0676
# epoch 195.0000, loss 0.2488, train error 0.0704
# validation loss 0.2419
# validation error 0.0674
# epoch 196.0000, loss 0.2482, train error 0.0703
# validation loss 0.2413
# validation error 0.0674
# epoch 197.0000, loss 0.2477, train error 0.0701
# validation loss 0.2408
# validation error 0.0671
# epoch 198.0000, loss 0.2471, train error 0.0699
# validation loss 0.2403
# validation error 0.0670
# epoch 199.0000, loss 0.2466, train error 0.0697
# validation loss 0.2398
# validation error 0.0670
# epoch 200.0000, loss 0.2460, train error 0.0695
# validation loss 0.2393
# validation error 0.0669
# epoch 201.0000, loss 0.2454, train error 0.0694
# validation loss 0.2388
# validation error 0.0667
# epoch 202.0000, loss 0.2449, train error 0.0693
# validation loss 0.2383
# validation error 0.0665
# epoch 203.0000, loss 0.2443, train error 0.0691
# validation loss 0.2378
# validation error 0.0665
# epoch 204.0000, loss 0.2438, train error 0.0690
# validation loss 0.2373
# validation error 0.0663
# epoch 205.0000, loss 0.2433, train error 0.0688
# validation loss 0.2368
# validation error 0.0661
# epoch 206.0000, loss 0.2427, train error 0.0687
# validation loss 0.2363
# validation error 0.0659
# epoch 207.0000, loss 0.2422, train error 0.0685
# validation loss 0.2358
# validation error 0.0658
# epoch 208.0000, loss 0.2416, train error 0.0684
# validation loss 0.2353
# validation error 0.0658
# epoch 209.0000, loss 0.2411, train error 0.0683
# validation loss 0.2348
# validation error 0.0656
# epoch 210.0000, loss 0.2406, train error 0.0682
# validation loss 0.2343
# validation error 0.0655
# epoch 211.0000, loss 0.2400, train error 0.0681
# validation loss 0.2338
# validation error 0.0650
# epoch 212.0000, loss 0.2395, train error 0.0680
# validation loss 0.2334
# validation error 0.0650
# epoch 213.0000, loss 0.2390, train error 0.0678
# validation loss 0.2329
# validation error 0.0650
# epoch 214.0000, loss 0.2385, train error 0.0677
# validation loss 0.2324
# validation error 0.0648
# epoch 215.0000, loss 0.2379, train error 0.0674
# validation loss 0.2319
# validation error 0.0647
# epoch 216.0000, loss 0.2374, train error 0.0673
# validation loss 0.2315
# validation error 0.0646
# epoch 217.0000, loss 0.2369, train error 0.0671
# validation loss 0.2310
# validation error 0.0646
# epoch 218.0000, loss 0.2364, train error 0.0669
# validation loss 0.2305
# validation error 0.0645
# epoch 219.0000, loss 0.2359, train error 0.0669
# validation loss 0.2301
# validation error 0.0642
# epoch 220.0000, loss 0.2354, train error 0.0667
# validation loss 0.2296
# validation error 0.0641
# epoch 221.0000, loss 0.2349, train error 0.0667
# validation loss 0.2291
# validation error 0.0637
# epoch 222.0000, loss 0.2344, train error 0.0664
# validation loss 0.2287
# validation error 0.0637
# epoch 223.0000, loss 0.2339, train error 0.0663
# validation loss 0.2282
# validation error 0.0637
# epoch 224.0000, loss 0.2334, train error 0.0662
# validation loss 0.2278
# validation error 0.0635
# epoch 225.0000, loss 0.2329, train error 0.0660
# validation loss 0.2273
# validation error 0.0633
# epoch 226.0000, loss 0.2324, train error 0.0659
# validation loss 0.2268
# validation error 0.0631
# epoch 227.0000, loss 0.2319, train error 0.0657
# validation loss 0.2264
# validation error 0.0630
# epoch 228.0000, loss 0.2314, train error 0.0656
# validation loss 0.2259
# validation error 0.0629
# epoch 229.0000, loss 0.2309, train error 0.0654
# validation loss 0.2255
# validation error 0.0626
# epoch 230.0000, loss 0.2304, train error 0.0653
# validation loss 0.2251
# validation error 0.0626
# epoch 231.0000, loss 0.2299, train error 0.0651
# validation loss 0.2246
# validation error 0.0625
# epoch 232.0000, loss 0.2295, train error 0.0650
# validation loss 0.2242
# validation error 0.0625
# epoch 233.0000, loss 0.2290, train error 0.0648
# validation loss 0.2237
# validation error 0.0623
# epoch 234.0000, loss 0.2285, train error 0.0646
# validation loss 0.2233
# validation error 0.0623
# epoch 235.0000, loss 0.2280, train error 0.0645
# validation loss 0.2229
# validation error 0.0623
# epoch 236.0000, loss 0.2276, train error 0.0643
# validation loss 0.2224
# validation error 0.0622
# epoch 237.0000, loss 0.2271, train error 0.0641
# validation loss 0.2220
# validation error 0.0621
# epoch 238.0000, loss 0.2266, train error 0.0640
# validation loss 0.2216
# validation error 0.0620
# epoch 239.0000, loss 0.2261, train error 0.0640
# validation loss 0.2211
# validation error 0.0619
# epoch 240.0000, loss 0.2257, train error 0.0637
# validation loss 0.2207
# validation error 0.0616
# epoch 241.0000, loss 0.2252, train error 0.0636
# validation loss 0.2203
# validation error 0.0610
# epoch 242.0000, loss 0.2248, train error 0.0634
# validation loss 0.2199
# validation error 0.0607
# epoch 243.0000, loss 0.2243, train error 0.0633
# validation loss 0.2194
# validation error 0.0605
# epoch 244.0000, loss 0.2238, train error 0.0633
# validation loss 0.2190
# validation error 0.0605
# epoch 245.0000, loss 0.2234, train error 0.0631
# validation loss 0.2186
# validation error 0.0604
# epoch 246.0000, loss 0.2229, train error 0.0631
# validation loss 0.2182
# validation error 0.0604
# epoch 247.0000, loss 0.2225, train error 0.0629
# validation loss 0.2178
# validation error 0.0604
# epoch 248.0000, loss 0.2220, train error 0.0628
# validation loss 0.2174
# validation error 0.0603
# epoch 249.0000, loss 0.2216, train error 0.0626
# validation loss 0.2170
# validation error 0.0602
# epoch 250.0000, loss 0.2211, train error 0.0626
# validation loss 0.2165
# validation error 0.0600
# epoch 251.0000, loss 0.2207, train error 0.0624
# validation loss 0.2161
# validation error 0.0599
# epoch 252.0000, loss 0.2202, train error 0.0623
# validation loss 0.2157
# validation error 0.0595
# epoch 253.0000, loss 0.2198, train error 0.0621
# validation loss 0.2153
# validation error 0.0595
# epoch 254.0000, loss 0.2194, train error 0.0619
# validation loss 0.2149
# validation error 0.0595
# epoch 255.0000, loss 0.2189, train error 0.0617
# validation loss 0.2145
# validation error 0.0595
# epoch 256.0000, loss 0.2185, train error 0.0617
# validation loss 0.2141
# validation error 0.0594
# epoch 257.0000, loss 0.2181, train error 0.0615
# validation loss 0.2137
# validation error 0.0592
# epoch 258.0000, loss 0.2176, train error 0.0614
# validation loss 0.2133
# validation error 0.0592
# epoch 259.0000, loss 0.2172, train error 0.0612
# validation loss 0.2129
# validation error 0.0591
# epoch 260.0000, loss 0.2168, train error 0.0611
# validation loss 0.2126
# validation error 0.0587
# epoch 261.0000, loss 0.2163, train error 0.0610
# validation loss 0.2122
# validation error 0.0585
# epoch 262.0000, loss 0.2159, train error 0.0609
# validation loss 0.2118
# validation error 0.0584
# epoch 263.0000, loss 0.2155, train error 0.0608
# validation loss 0.2114
# validation error 0.0584
# epoch 264.0000, loss 0.2151, train error 0.0606
# validation loss 0.2110
# validation error 0.0583
# epoch 265.0000, loss 0.2147, train error 0.0605
# validation loss 0.2106
# validation error 0.0583
# epoch 266.0000, loss 0.2142, train error 0.0604
# validation loss 0.2102
# validation error 0.0583
# epoch 267.0000, loss 0.2138, train error 0.0602
# validation loss 0.2099
# validation error 0.0580
# epoch 268.0000, loss 0.2134, train error 0.0600
# validation loss 0.2095
# validation error 0.0581
# epoch 269.0000, loss 0.2130, train error 0.0599
# validation loss 0.2091
# validation error 0.0580
# epoch 270.0000, loss 0.2126, train error 0.0599
# validation loss 0.2087
# validation error 0.0580
# epoch 271.0000, loss 0.2122, train error 0.0597
# validation loss 0.2083
# validation error 0.0580
# epoch 272.0000, loss 0.2118, train error 0.0596
# validation loss 0.2080
# validation error 0.0578
# epoch 273.0000, loss 0.2114, train error 0.0595
# validation loss 0.2076
# validation error 0.0578
# epoch 274.0000, loss 0.2110, train error 0.0593
# validation loss 0.2072
# validation error 0.0576
# epoch 275.0000, loss 0.2105, train error 0.0592
# validation loss 0.2069
# validation error 0.0575
# epoch 276.0000, loss 0.2101, train error 0.0590
# validation loss 0.2065
# validation error 0.0574
# epoch 277.0000, loss 0.2097, train error 0.0589
# validation loss 0.2061
# validation error 0.0572
# epoch 278.0000, loss 0.2093, train error 0.0588
# validation loss 0.2058
# validation error 0.0572
# epoch 279.0000, loss 0.2090, train error 0.0587
# validation loss 0.2054
# validation error 0.0572
# epoch 280.0000, loss 0.2086, train error 0.0586
# validation loss 0.2050
# validation error 0.0572
# epoch 281.0000, loss 0.2082, train error 0.0585
# validation loss 0.2047
# validation error 0.0571
# epoch 282.0000, loss 0.2078, train error 0.0584
# validation loss 0.2043
# validation error 0.0569
# epoch 283.0000, loss 0.2074, train error 0.0583
# validation loss 0.2040
# validation error 0.0569
# epoch 284.0000, loss 0.2070, train error 0.0581
# validation loss 0.2036
# validation error 0.0568
# epoch 285.0000, loss 0.2066, train error 0.0581
# validation loss 0.2033
# validation error 0.0567
# epoch 286.0000, loss 0.2062, train error 0.0579
# validation loss 0.2029
# validation error 0.0565
# epoch 287.0000, loss 0.2058, train error 0.0578
# validation loss 0.2026
# validation error 0.0563
# epoch 288.0000, loss 0.2054, train error 0.0576
# validation loss 0.2022
# validation error 0.0562
# epoch 289.0000, loss 0.2051, train error 0.0575
# validation loss 0.2019
# validation error 0.0561
# epoch 290.0000, loss 0.2047, train error 0.0574
# validation loss 0.2015
# validation error 0.0559
# epoch 291.0000, loss 0.2043, train error 0.0573
# validation loss 0.2012
# validation error 0.0558
# epoch 292.0000, loss 0.2039, train error 0.0572
# validation loss 0.2008
# validation error 0.0558
# epoch 293.0000, loss 0.2035, train error 0.0570
# validation loss 0.2005
# validation error 0.0555
# epoch 294.0000, loss 0.2032, train error 0.0569
# validation loss 0.2001
# validation error 0.0553
# epoch 295.0000, loss 0.2028, train error 0.0568
# validation loss 0.1998
# validation error 0.0551
# epoch 296.0000, loss 0.2024, train error 0.0567
# validation loss 0.1995
# validation error 0.0551
# epoch 297.0000, loss 0.2021, train error 0.0566
# validation loss 0.1991
# validation error 0.0550
# epoch 298.0000, loss 0.2017, train error 0.0566
# validation loss 0.1988
# validation error 0.0547
# epoch 299.0000, loss 0.2013, train error 0.0565
# validation loss 0.1985
# validation error 0.0547
# epoch 300.0000, loss 0.2009, train error 0.0564
# validation loss 0.1981
# validation error 0.0546
# epoch 301.0000, loss 0.2006, train error 0.0563
# validation loss 0.1978
# validation error 0.0544
# epoch 302.0000, loss 0.2002, train error 0.0561
# validation loss 0.1975
# validation error 0.0544
# epoch 303.0000, loss 0.1999, train error 0.0560
# validation loss 0.1971
# validation error 0.0544
# epoch 304.0000, loss 0.1995, train error 0.0560
# validation loss 0.1968
# validation error 0.0544
# epoch 305.0000, loss 0.1991, train error 0.0558
# validation loss 0.1965
# validation error 0.0544
# epoch 306.0000, loss 0.1988, train error 0.0558
# validation loss 0.1961
# validation error 0.0543
# epoch 307.0000, loss 0.1984, train error 0.0558
# validation loss 0.1958
# validation error 0.0543
# epoch 308.0000, loss 0.1981, train error 0.0558
# validation loss 0.1955
# validation error 0.0543
# epoch 309.0000, loss 0.1977, train error 0.0556
# validation loss 0.1952
# validation error 0.0543
# epoch 310.0000, loss 0.1974, train error 0.0555
# validation loss 0.1948
# validation error 0.0542
# epoch 311.0000, loss 0.1970, train error 0.0554
# validation loss 0.1945
# validation error 0.0541
# epoch 312.0000, loss 0.1966, train error 0.0553
# validation loss 0.1942
# validation error 0.0539
# epoch 313.0000, loss 0.1963, train error 0.0552
# validation loss 0.1939
# validation error 0.0539
# epoch 314.0000, loss 0.1960, train error 0.0551
# validation loss 0.1936
# validation error 0.0539
# epoch 315.0000, loss 0.1956, train error 0.0551
# validation loss 0.1933
# validation error 0.0539
# epoch 316.0000, loss 0.1953, train error 0.0551
# validation loss 0.1929
# validation error 0.0537
# epoch 317.0000, loss 0.1949, train error 0.0549
# validation loss 0.1926
# validation error 0.0536
# epoch 318.0000, loss 0.1946, train error 0.0548
# validation loss 0.1923
# validation error 0.0536
# epoch 319.0000, loss 0.1942, train error 0.0546
# validation loss 0.1920
# validation error 0.0533
# epoch 320.0000, loss 0.1939, train error 0.0546
# validation loss 0.1917
# validation error 0.0530
# epoch 321.0000, loss 0.1935, train error 0.0544
# validation loss 0.1914
# validation error 0.0531
# epoch 322.0000, loss 0.1932, train error 0.0543
# validation loss 0.1911
# validation error 0.0531
# epoch 323.0000, loss 0.1929, train error 0.0542
# validation loss 0.1908
# validation error 0.0529
# epoch 324.0000, loss 0.1925, train error 0.0541
# validation loss 0.1905
# validation error 0.0529
# epoch 325.0000, loss 0.1922, train error 0.0541
# validation loss 0.1902
# validation error 0.0529
# epoch 326.0000, loss 0.1919, train error 0.0540
# validation loss 0.1899
# validation error 0.0529
# epoch 327.0000, loss 0.1915, train error 0.0539
# validation loss 0.1895
# validation error 0.0528
# epoch 328.0000, loss 0.1912, train error 0.0538
# validation loss 0.1892
# validation error 0.0528
# epoch 329.0000, loss 0.1909, train error 0.0538
# validation loss 0.1889
# validation error 0.0528
# epoch 330.0000, loss 0.1905, train error 0.0536
# validation loss 0.1886
# validation error 0.0527
# epoch 331.0000, loss 0.1902, train error 0.0536
# validation loss 0.1884
# validation error 0.0527
# epoch 332.0000, loss 0.1899, train error 0.0535
# validation loss 0.1881
# validation error 0.0526
# epoch 333.0000, loss 0.1896, train error 0.0534
# validation loss 0.1878
# validation error 0.0526
# epoch 334.0000, loss 0.1892, train error 0.0533
# validation loss 0.1875
# validation error 0.0526
# epoch 335.0000, loss 0.1889, train error 0.0532
# validation loss 0.1872
# validation error 0.0526
# epoch 336.0000, loss 0.1886, train error 0.0531
# validation loss 0.1869
# validation error 0.0525
# epoch 337.0000, loss 0.1883, train error 0.0531
# validation loss 0.1866
# validation error 0.0525
# epoch 338.0000, loss 0.1879, train error 0.0531
# validation loss 0.1863
# validation error 0.0523
# epoch 339.0000, loss 0.1876, train error 0.0529
# validation loss 0.1860
# validation error 0.0520
# epoch 340.0000, loss 0.1873, train error 0.0529
# validation loss 0.1857
# validation error 0.0518
# epoch 341.0000, loss 0.1870, train error 0.0527
# validation loss 0.1854
# validation error 0.0517
# epoch 342.0000, loss 0.1867, train error 0.0527
# validation loss 0.1851
# validation error 0.0514
# epoch 343.0000, loss 0.1864, train error 0.0526
# validation loss 0.1849
# validation error 0.0513
# epoch 344.0000, loss 0.1860, train error 0.0526
# validation loss 0.1846
# validation error 0.0511
# epoch 345.0000, loss 0.1857, train error 0.0525
# validation loss 0.1843
# validation error 0.0511
# epoch 346.0000, loss 0.1854, train error 0.0524
# validation loss 0.1840
# validation error 0.0507
# epoch 347.0000, loss 0.1851, train error 0.0522
# validation loss 0.1837
# validation error 0.0506
# epoch 348.0000, loss 0.1848, train error 0.0520
# validation loss 0.1835
# validation error 0.0505
# epoch 349.0000, loss 0.1845, train error 0.0519
# validation loss 0.1832
# validation error 0.0504
# epoch 350.0000, loss 0.1842, train error 0.0518
# validation loss 0.1829
# validation error 0.0502
# Duration: 3489.1s

# %%
print(nn.plot_data)
nn.plot_data[:,0]
# Out:
# [[0.18234289 0.18358888 0.        ]
#  [0.11170035 0.11936705 1.        ]]
# array([0.18234289, 0.11170035])

# %%
# add plotlib
import matplotlib.pyplot as plt

# %%
#plot data
#EXAMPLE1
#complete, y_complete, X_test, y_test, learning_rate=0.2, 
#max_epochs=50, batch_size=50, y_one_hot=True, descent_type="sgd"
example1=nn.plot_data
plt.figure(figsize=(13, 10))
plt.plot(example1[:,0], label="Training loss")
plt.plot(example1[:,1], label="Test loss")
plt.legend(loc="best")

# %%
#plot data
#EXAMPLE1
example2=nn.plot_data
plt.figure(figsize=(13, 10))
plt.plot(example2[:,0], label="Training loss")
plt.plot(example2[:,1], label="Test loss")
plt.legend(loc="best")
